# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Data Reading and Train test split

# %%
df=pd.read_csv('cancer_classification.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   mean radius              569 non-null    float64
#  1   mean texture             569 non-null    float64
#  2   mean perimeter           569 non-null    float64
#  3   mean area                569 non-null    float64
#  4   mean smoothness          569 non-null    float64
#  5   mean compactness         569 non-null    float64
#  6   mean concavity           569 non-null    float64
#  7   mean concave points      569 non-null    float64
#  8   mean symmetry            569 non-null    float64
#  9   mean fractal dimension   569 non-null    float64
#  10  radius error             569 non-null    float64
#  11  texture error            569 non-null    float64
#  12  perimeter error          569 non-null    float64
#  13  area error               569 non-null    float64
#  14  smoothness error         569 non-null    float64
#  15  compactness error        569 non-null    float64
#  16  concavity error          569 non-null    float64
#  17  concave points error     569 non-null    float64
#  18  symmetry error           569 non-null    float64
#  19  fractal dimension error  569 non-null    float64
#  20  worst radius             569 non-null    float64
#  21  worst texture            569 non-null    float64
#  22  worst perimeter          569 non-null    float64
#  23  worst area               569 non-null    float64
#  24  worst smoothness         569 non-null    float64
#  25  worst compactness        569 non-null    float64
#  26  worst concavity          569 non-null    float64
#  27  worst concave points     569 non-null    float64
#  28  worst symmetry           569 non-null    float64
#  29  worst fractal dimension  569 non-null    float64
#  30  benign_0__mal_1          569 non-null    int64
# dtypes: float64(30), int64(1)
# memory usage: 137.9 KB

# %%
df.describe()
# Out:
#        mean radius  mean texture  mean perimeter    mean area  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        mean smoothness  mean compactness  mean concavity  mean concave points  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# 25%           0.086370          0.064920        0.029560             0.020310
# 50%           0.095870          0.092630        0.061540             0.033500
# 75%           0.105300          0.130400        0.130700             0.074000
# max           0.163400          0.345400        0.426800             0.201200
#
#        mean symmetry  mean fractal dimension  ...  worst texture  \
# count     569.000000              569.000000  ...     569.000000
# mean        0.181162                0.062798  ...      25.677223
# std         0.027414                0.007060  ...       6.146258
# min         0.106000                0.049960  ...      12.020000
# 25%         0.161900                0.057700  ...      21.080000
# 50%         0.179200                0.061540  ...      25.410000
# 75%         0.195700                0.066120  ...      29.720000
# max         0.304000                0.097440  ...      49.540000
#
#        worst perimeter   worst area  worst smoothness  worst compactness  \
# count       569.000000   569.000000        569.000000         569.000000
# mean        107.261213   880.583128          0.132369           0.254265
# std          33.602542   569.356993          0.022832           0.157336
# min          50.410000   185.200000          0.071170           0.027290
# 25%          84.110000   515.300000          0.116600           0.147200
# 50%          97.660000   686.500000          0.131300           0.211900
# 75%         125.400000  1084.000000          0.146000           0.339100
# max         251.200000  4254.000000          0.222600           1.058000
#
#        worst concavity  worst concave points  worst symmetry  \
# count       569.000000            569.000000      569.000000
# mean          0.272188              0.114606        0.290076
# std           0.208624              0.065732        0.061867
# min           0.000000              0.000000        0.156500
# 25%           0.114500              0.064930        0.250400
# 50%           0.226700              0.099930        0.282200
# 75%           0.382900              0.161400        0.317900
# max           1.252000              0.291000        0.663800
#
#        worst fractal dimension  benign_0__mal_1
# count               569.000000       569.000000
# mean                  0.083946         0.627417
# std                   0.018061         0.483918
# min                   0.055040         0.000000
# 25%                   0.071460         0.000000
# 50%                   0.080040         1.000000
# 75%                   0.092080         1.000000
# max                   0.207500         1.000000
#
# [8 rows x 31 columns]

# %%
df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# 0                 0.07871  ...          17.33           184.60      2019.0
# 1                 0.05667  ...          23.41           158.80      1956.0
# 2                 0.05999  ...          25.53           152.50      1709.0
# 3                 0.09744  ...          26.50            98.87       567.7
# 4                 0.05883  ...          16.67           152.20      1575.0
#
#    worst smoothness  worst compactness  worst concavity  worst concave points  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    worst symmetry  worst fractal dimension  benign_0__mal_1
# 0          0.4601                  0.11890                0
# 1          0.2750                  0.08902                0
# 2          0.3613                  0.08758                0
# 3          0.6638                  0.17300                0
# 4          0.2364                  0.07678                0
#
# [5 rows x 31 columns]

# %%
x=df.drop('benign_0__mal_1',axis=1).values
y=df['benign_0__mal_1'].values

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=42,test_size=0.30)

# %% [markdown]
# ## Transforming the data

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()

# %%
scaler.fit(x_train)
# Out:
# MinMaxScaler()

# %%
x_train=scaler.fit_transform(x_train)
x_test=scaler.fit_transform(x_test)

# %% [markdown]
# ## Creating the model

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Activation,Dropout

# %%
x_train.shape
# Out:
# (398, 30)

# %%
model=Sequential()

model.add(Dense(units=30,activation='relu'))
model.add(Dense(units=15,activation='relu'))
model.add(Dense(units=1,activation='sigmoid'))

model.compile(loss='binary_crossentropy',optimizer='adam')

# %%
from tensorflow.keras.callbacks import EarlyStopping
early_stop=EarlyStopping(monitor='val_loss',mode='min',verbose=1,patience=25)

# %%
model.fit(x=x_train,y=y_train,epochs=600,validation_data=(x_test,y_test),verbose=1,callbacks=[early_stop])
# Out:
# Epoch 1/600
# 13/13 [==============================] - 1s 26ms/step - loss: 0.6467 - val_loss: 0.6036
# Epoch 2/600
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5972 - val_loss: 0.5465
# Epoch 3/600
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5489 - val_loss: 0.4833
# Epoch 4/600
# 13/13 [==============================] - 0s 6ms/step - loss: 0.4973 - val_loss: 0.4289
# Epoch 5/600
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4476 - val_loss: 0.3763
# Epoch 6/600
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4017 - val_loss: 0.3341
# Epoch 7/600
# 13/13 [==============================] - 0s 7ms/step - loss: 0.3620 - val_loss: 0.2981
# Epoch 8/600
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3289 - val_loss: 0.2655
# Epoch 9/600
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3017 - val_loss: 0.2412
# Epoch 10/600
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2782 - val_loss: 0.2205
# Epoch 11/600
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2584 - val_loss: 0.2025
# Epoch 12/600
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2421 - val_loss: 0.1869
# Epoch 13/600
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2272 - val_loss: 0.1734
# Epoch 14/600
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2203 - val_loss: 0.1619
# Epoch 15/600
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2082 - val_loss: 0.1517
# Epoch 16/600
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1936 - val_loss: 0.1439
# Epoch 17/600
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1885 - val_loss: 0.1334
# Epoch 18/600
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1779 - val_loss: 0.1280
# Epoch 19/600
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1710 - val_loss: 0.1195
# Epoch 20/600
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1611 - val_loss: 0.1163
# Epoch 21/600
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1537 - val_loss: 0.1075
# Epoch 22/600
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1479 - val_loss: 0.1056
# Epoch 23/600
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1428 - val_loss: 0.1002
# Epoch 24/600
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1375 - val_loss: 0.0965
# Epoch 25/600
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1315 - val_loss: 0.0979
# Epoch 26/600
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1264 - val_loss: 0.0962
# Epoch 27/600
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1233 - val_loss: 0.0969
# Epoch 28/600
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1183 - val_loss: 0.1002
# Epoch 29/600
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1168 - val_loss: 0.0964
# Epoch 30/600
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1101 - val_loss: 0.0962
# Epoch 31/600
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1058 - val_loss: 0.0958
# Epoch 32/600
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1025 - val_loss: 0.1019
# Epoch 33/600
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0997 - val_loss: 0.1016
# Epoch 34/600
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0967 - val_loss: 0.1007
# Epoch 35/600
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0945 - val_loss: 0.1101
# Epoch 36/600
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0963 - val_loss: 0.1143
# Epoch 37/600
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0906 - val_loss: 0.1063
# Epoch 38/600
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0867 - val_loss: 0.1165
# Epoch 39/600
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0856 - val_loss: 0.1070
# Epoch 40/600
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0861 - val_loss: 0.1170
# Epoch 41/600
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0820 - val_loss: 0.1109
# Epoch 42/600
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0824 - val_loss: 0.1232
# Epoch 43/600
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0805 - val_loss: 0.1342
# Epoch 44/600
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0802 - val_loss: 0.1240
# Epoch 45/600
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0781 - val_loss: 0.1330
# Epoch 46/600
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0751 - val_loss: 0.1208
# Epoch 47/600
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0749 - val_loss: 0.1354
# Epoch 48/600
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0721 - val_loss: 0.1486
# Epoch 49/600
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0714 - val_loss: 0.1356
# Epoch 50/600
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0703 - val_loss: 0.1376
# Epoch 51/600
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0694 - val_loss: 0.1500
# Epoch 52/600
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0691 - val_loss: 0.1616
# Epoch 53/600
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0686 - val_loss: 0.1485
# Epoch 54/600
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0673 - val_loss: 0.1486
# Epoch 55/600
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0660 - val_loss: 0.1528
# Epoch 56/600
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0660 - val_loss: 0.1649
# Epoch 56: early stopping

# %%
model_losses=pd.DataFrame(model.history.history)

# %%
model_losses.plot()
# Out:
# <AxesSubplot:>

# %%
predictions=model.predict(x_test)
threshold=0.5
predictions=np.where(predictions>threshold,1,0)
# Out:
# 6/6 [==============================] - 4s 2ms/step

# %% [markdown]
# ## Evaluating the model

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.98      0.92        63
#            1       0.99      0.91      0.95       108
#
#     accuracy                           0.94       171
#    macro avg       0.93      0.95      0.93       171
# weighted avg       0.94      0.94      0.94       171

# %%
print(confusion_matrix(y_test,predictions))
# Out:
# [[62  1]
#  [10 98]]
